# %%
import numpy as np
import pandas as pd
import re
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
import os
from tqdm import tqdm

# %%
RFID_COC = pd.read_csv('rfid_cocaine.csv', index_col=0)

# %%
RFID_OXY = pd.read_csv('rfid_oxycodone.csv', index_col=0)

# %%
# coc lga
input_path = '/Users/yunyihuang/George Lab Dropbox/George_Lab/Experiments/DataStream/DataSource/excel_output_files/COCAINE/LGA'
output_path = '/Users/yunyihuang/Desktop/gl_data/TRIAL/COC_LGA'

parsers = [r"(\A[A-Z]+[0-9]+[A-Z|0-9]{1})(C[0-9]{2})HS[OXY|COCAINE]*((?:LGA|SHA)[0-9]{2})",
           r"(\AC[0-9]{2})HS[OXY]*((?:LGA|SHA)[0-9]{2})"]
drug = 'cocaine'

# %%
# oxy lga
input_path = '/Users/yunyihuang/George Lab Dropbox/George_Lab/Experiments/DataStream/DataSource/excel_output_files/OXYCODONE/LGA'
output_path = '/Users/yunyihuang/Desktop/gl_data/TRIAL/OXY_LGA'

parsers = [r"(\A[A-Z]+[0-9]+[A-Z|0-9]{1})(C[0-9]{2})HS[OXY|COCAINE]*((?:LGA|SHA)[0-9]{2})",
           r"(\AC[0-9]{2})HS[OXY]*((?:LGA|SHA)[0-9]{2})"]
drug = 'oxycodone'

# %%
# coc sha
input_path = '/Users/yunyihuang/George Lab Dropbox/George_Lab/Experiments/DataStream/DataSource/excel_output_files/COCAINE/SHA'
output_path = '/Users/yunyihuang/Desktop/gl_data/TRIAL/COC_SHA'

parsers = [r"(\A[A-Z]+[0-9]+[A-Z|0-9]{1})(C[0-9]{2})HS[OXY|COCAINE]*((?:LGA|SHA)[0-9]{2})",
           r"(\AC[0-9]{2})HS[OXY]*((?:LGA|SHA)[0-9]{2})"]
drug = 'cocaine'

# %%
# oxy sha
input_path = '/Users/yunyihuang/George Lab Dropbox/George_Lab/Experiments/DataStream/DataSource/excel_output_files/OXYCODONE/SHA'
output_path = '/Users/yunyihuang/Desktop/gl_data/TRIAL/OXY_SHA'

parsers = [r"(\A[A-Z]+[0-9]+[A-Z|0-9]{1})(C[0-9]{2})HS[OXY|COCAINE]*((?:LGA|SHA)[0-9]{2})",
           r"(\AC[0-9]{2})HS[OXY]*((?:LGA|SHA)[0-9]{2})"]
drug = 'oxycodone'

# %%
files = sorted([i for i in sorted(os.listdir(input_path)) if i != '.DS_Store' and ('C21' not in i)
        and ('duplicates' not in i) and ('problem' not in i) and ('SHA' in i)])
files
# Out:
# ['BSB273BC08HSSHA01_output.xlsx',
#  'BSB273BC08HSSHA02_output.xlsx',
#  'BSB273BC08HSSHA03_output.xlsx',
#  'BSB273BC08HSSHA04_output.xlsx',
#  'BSB273BC08HSSHA05_output.xlsx',
#  'BSB273BC08HSSHA06_output.xlsx',
#  'BSB273BC08HSSHA07_output.xlsx',
#  'BSB273BC08HSSHA08_output.xlsx',
#  'BSB273BC08HSSHA09_output.xlsx',
#  'BSB273BC08HSSHA10_output.xlsx',
#  'BSB273BC09HSSHA01_output.xlsx',
#  'BSB273BC09HSSHA02_output.xlsx',
#  'BSB273BC09HSSHA03_output.xlsx',
#  'BSB273BC09HSSHA04_output.xlsx',
#  'BSB273BC09HSSHA05_output.xlsx',
#  'BSB273BC09HSSHA06_output.xlsx',
#  'BSB273BC09HSSHA07_output.xlsx',
#  'BSB273BC09HSSHA08_output.xlsx',
#  'BSB273BC09HSSHA09_output.xlsx',
#  'BSB273BC09HSSHA10_output.xlsx',
#  'BSB273BC10HSSHA01_output.xlsx',
#  'BSB273BC10HSSHA02_output.xlsx',
#  'BSB273BC10HSSHA03_output.xlsx',
#  'BSB273BC11HSSHA01_output.xlsx',
#  'BSB273BC11HSSHA02_output.xlsx',
#  'BSB273BC11HSSHA03_output.xlsx',
#  'BSB273BC11HSSHA04_output.xlsx',
#  'BSB273BC11HSSHA05_output.xlsx',
#  'BSB273BC11HSSHA06_output.xlsx',
#  'BSB273BC11HSSHA08_output.xlsx',
#  'BSB273BC11HSSHA09_output.xlsx',
#  'BSB273BC11HSSHA10_output.xlsx',
#  'BSB273BC13HSSHA01_output.xlsx',
#  'BSB273BC13HSSHA02_output.xlsx',
#  'BSB273BC13HSSHA03_output.xlsx',
#  'BSB273BC13HSSHA04_output.xlsx',
#  'BSB273BC13HSSHA05_output.xlsx',
#  'BSB273BC13HSSHA06_output.xlsx',
#  'BSB273BC13HSSHA07_output.xlsx',
#  'BSB273BC13HSSHA08_output.xlsx',
#  'BSB273BC13HSSHA09_output.xlsx',
#  'BSB273BC13HSSHA10_output.xlsx',
#  'BSB273BC14HSSHA01_output.xlsx',
#  'BSB273BC14HSSHA02_output.xlsx',
#  'BSB273BC14HSSHA03_output.xlsx',
#  'BSB273BC14HSSHA04_output.xlsx',
#  'BSB273BC14HSSHA05_output.xlsx',
#  'BSB273BC14HSSHA06_output.xlsx',
#  'BSB273BC14HSSHA07_output.xlsx',
#  'BSB273BC14HSSHA08_output.xlsx',
#  'BSB273BC14HSSHA09_output.xlsx',
#  'BSB273BC14HSSHA10_output.xlsx',
#  'BSB273BC16HSSHA01_output.xlsx',
#  'BSB273BC16HSSHA02_output.xlsx',
#  'BSB273BC16HSSHA03_output.xlsx',
#  'BSB273BC16HSSHA04_output.xlsx',
#  'BSB273BC16HSSHA05_output.xlsx',
#  'BSB273BC16HSSHA06_output.xlsx',
#  'BSB273BC16HSSHA07_output.xlsx',
#  'BSB273BC16HSSHA08_output.xlsx',
#  'BSB273BC16HSSHA09_output.xlsx',
#  'BSB273BC16HSSHA10_output.xlsx',
#  'BSB273BC17HSSHA01_output.xlsx',
#  'BSB273BC17HSSHA02_output.xlsx',
#  'BSB273BC17HSSHA03_output.xlsx',
#  'BSB273BC17HSSHA04_output.xlsx',
#  'BSB273BC17HSSHA05_output.xlsx',
#  'BSB273BC17HSSHA06_output.xlsx',
#  'BSB273BC17HSSHA07_output.xlsx',
#  'BSB273BC17HSSHA08_output.xlsx',
#  'BSB273BC17HSSHA09_output.xlsx',
#  'BSB273BC17HSSHA10_output.xlsx',
#  'BSB273CC08HSSHA01_output.xlsx',
#  'BSB273CC08HSSHA02_output.xlsx',
#  'BSB273CC08HSSHA03_output.xlsx',
#  'BSB273CC08HSSHA04_output.xlsx',
#  'BSB273CC08HSSHA05_output.xlsx',
#  'BSB273CC08HSSHA06_output.xlsx',
#  'BSB273CC08HSSHA07_output.xlsx',
#  'BSB273CC08HSSHA08_output.xlsx',
#  'BSB273CC08HSSHA09_output.xlsx',
#  'BSB273CC08HSSHA10_output.xlsx',
#  'BSB273CC09HSSHA01_output.xlsx',
#  'BSB273CC09HSSHA02_output.xlsx',
#  'BSB273CC09HSSHA03_output.xlsx',
#  'BSB273CC09HSSHA04_output.xlsx',
#  'BSB273CC09HSSHA05_output.xlsx',
#  'BSB273CC09HSSHA06_output.xlsx',
#  'BSB273CC09HSSHA07_output.xlsx',
#  'BSB273CC09HSSHA08_output.xlsx',
#  'BSB273CC09HSSHA09_output.xlsx',
#  'BSB273CC09HSSHA10_output.xlsx',
#  'BSB273CC10HSCOCAINESHA01_output.xlsx',
#  'BSB273CC10HSCOCAINESHA02_output.xlsx',
#  'BSB273CC10HSCOCAINESHA03_output.xlsx',
#  'BSB273CC10HSCOCAINESHA04_output.xlsx',
#  'BSB273CC10HSCOCAINESHA05_output.xlsx',
#  'BSB273CC10HSCOCAINESHA06_output.xlsx',
#  'BSB273CC10HSCOCAINESHA07_output.xlsx',
#  'BSB273CC10HSCOCAINESHA08_output.xlsx',
#  'BSB273CC10HSCOCAINESHA09_output.xlsx',
#  'BSB273CC10HSCOCAINESHA10_output.xlsx',
#  'BSB273CC11HSSHA01_output.xlsx',
#  'BSB273CC11HSSHA02_output.xlsx',
#  'BSB273CC11HSSHA03_output.xlsx',
#  'BSB273CC11HSSHA04_output.xlsx',
#  'BSB273CC11HSSHA05_output.xlsx',
#  'BSB273CC11HSSHA06_output.xlsx',
#  'BSB273CC11HSSHA08_output.xlsx',
#  'BSB273CC11HSSHA09_output.xlsx',
#  'BSB273CC11HSSHA10_output.xlsx',
#  'BSB273CC13HSSHA01_output.xlsx',
#  'BSB273CC13HSSHA02_output.xlsx',
#  'BSB273CC13HSSHA03_output.xlsx',
#  'BSB273CC13HSSHA04_output.xlsx',
#  'BSB273CC13HSSHA05_output.xlsx',
#  'BSB273CC13HSSHA06_output.xlsx',
#  'BSB273CC13HSSHA07_output.xlsx',
#  'BSB273CC13HSSHA08_output.xlsx',
#  'BSB273CC13HSSHA09_output.xlsx',
#  'BSB273CC13HSSHA10_output.xlsx',
#  'BSB273CC14HSSHA01_output.xlsx',
#  'BSB273CC14HSSHA02_output.xlsx',
#  'BSB273CC14HSSHA03_output.xlsx',
#  'BSB273CC14HSSHA04_output.xlsx',
#  'BSB273CC14HSSHA05_output.xlsx',
#  'BSB273CC14HSSHA06_output.xlsx',
#  'BSB273CC14HSSHA07_output.xlsx',
#  'BSB273CC14HSSHA08_output.xlsx',
#  'BSB273CC14HSSHA09_output.xlsx',
#  'BSB273CC14HSSHA10_output.xlsx',
#  'BSB273CC15HSSHA01_output.xlsx',
#  'BSB273CC15HSSHA02_output.xlsx',
#  'BSB273CC15HSSHA03_output.xlsx',
#  'BSB273CC15HSSHA04_output.xlsx',
#  'BSB273CC15HSSHA05_output.xlsx',
#  'BSB273CC15HSSHA06_output.xlsx',
#  'BSB273CC15HSSHA07_output.xlsx',
#  'BSB273CC15HSSHA08_output.xlsx',
#  'BSB273CC15HSSHA09_output.xlsx',
#  'BSB273CC15HSSHA10_output.xlsx',
#  'BSB273CC15HSSHA11_output.xlsx',
#  'BSB273CC16HSSHA01_output.xlsx',
#  'BSB273CC16HSSHA02_output.xlsx',
#  'BSB273CC16HSSHA03_output.xlsx',
#  'BSB273CC16HSSHA04_output.xlsx',
#  'BSB273CC16HSSHA05_output.xlsx',
#  'BSB273CC16HSSHA06_output.xlsx',
#  'BSB273CC16HSSHA07_output.xlsx',
#  'BSB273CC16HSSHA08_output.xlsx',
#  'BSB273CC16HSSHA09_output.xlsx',
#  'BSB273CC16HSSHA10_output.xlsx',
#  'BSB273CC17HSSHA01_output.xlsx',
#  'BSB273CC17HSSHA02_output.xlsx',
#  'BSB273CC17HSSHA03_output.xlsx',
#  'BSB273CC17HSSHA04_output.xlsx',
#  'BSB273CC17HSSHA05_output.xlsx',
#  'BSB273CC17HSSHA06_output.xlsx',
#  'BSB273CC17HSSHA07_output.xlsx',
#  'BSB273CC17HSSHA08_output.xlsx',
#  'BSB273CC17HSSHA09_output.xlsx',
#  'BSB273CC17HSSHA10_output.xlsx',
#  'BSB273DC08HSSHA01_output.xlsx',
#  'BSB273DC08HSSHA02_output.xlsx',
#  'BSB273DC08HSSHA03_output.xlsx',
#  'BSB273DC08HSSHA04_output.xlsx',
#  'BSB273DC08HSSHA05_output.xlsx',
#  'BSB273DC08HSSHA06_output.xlsx',
#  'BSB273DC08HSSHA07_output.xlsx',
#  'BSB273DC08HSSHA08_output.xlsx',
#  'BSB273DC08HSSHA09_output.xlsx',
#  'BSB273DC08HSSHA10_output.xlsx',
#  'BSB273DC09HSSHA01_output.xlsx',
#  'BSB273DC09HSSHA02_output.xlsx',
#  'BSB273DC09HSSHA03_output.xlsx',
#  'BSB273DC09HSSHA04_output.xlsx',
#  'BSB273DC09HSSHA05_output.xlsx',
#  'BSB273DC09HSSHA06_output.xlsx',
#  'BSB273DC09HSSHA07_output.xlsx',
#  'BSB273DC09HSSHA08_output.xlsx',
#  'BSB273DC09HSSHA09_output.xlsx',
#  'BSB273DC09HSSHA10_output.xlsx',
#  'BSB273DC10HSCOCAINESHA01_output.xlsx',
#  'BSB273DC10HSCOCAINESHA02_output.xlsx',
#  'BSB273DC10HSCOCAINESHA03_output.xlsx',
#  'BSB273DC10HSCOCAINESHA04_output.xlsx',
#  'BSB273DC10HSCOCAINESHA05_output.xlsx',
#  'BSB273DC10HSCOCAINESHA06_output.xlsx',
#  'BSB273DC10HSCOCAINESHA07_output.xlsx',
#  'BSB273DC10HSCOCAINESHA08_output.xlsx',
#  'BSB273DC10HSCOCAINESHA09_output.xlsx',
#  'BSB273DC10HSCOCAINESHA10_output.xlsx',
#  'BSB273DC11HSSHA01_output.xlsx',
#  'BSB273DC11HSSHA02_output.xlsx',
#  'BSB273DC11HSSHA03_output.xlsx',
#  'BSB273DC11HSSHA04_output.xlsx',
#  'BSB273DC11HSSHA05_output.xlsx',
#  'BSB273DC11HSSHA06_output.xlsx',
#  'BSB273DC11HSSHA08_output.xlsx',
#  'BSB273DC11HSSHA09_output.xlsx',
#  'BSB273DC11HSSHA10_output.xlsx',
#  'BSB273DC13HSSHA01_output.xlsx',
#  'BSB273DC13HSSHA02_output.xlsx',
#  'BSB273DC13HSSHA03_output.xlsx',
#  'BSB273DC13HSSHA04_output.xlsx',
#  'BSB273DC13HSSHA05_output.xlsx',
#  'BSB273DC13HSSHA06_output.xlsx',
#  'BSB273DC13HSSHA07_output.xlsx',
#  'BSB273DC13HSSHA08_output.xlsx',
#  'BSB273DC13HSSHA09_output.xlsx',
#  'BSB273DC13HSSHA10_output.xlsx',
#  'BSB273DC14HSSHA01_output.xlsx',
#  'BSB273DC14HSSHA02_output.xlsx',
#  'BSB273DC14HSSHA03_output.xlsx',
#  'BSB273DC14HSSHA04_output.xlsx',
#  'BSB273DC14HSSHA05_output.xlsx',
#  'BSB273DC14HSSHA06_output.xlsx',
#  'BSB273DC14HSSHA07_output.xlsx',
#  'BSB273DC14HSSHA08_output.xlsx',
#  'BSB273DC14HSSHA09_output.xlsx',
#  'BSB273DC14HSSHA10_output.xlsx',
#  'BSB273DC15HSSHA01_output.xlsx',
#  'BSB273DC15HSSHA02_output.xlsx',
#  'BSB273DC15HSSHA03_output.xlsx',
#  'BSB273DC15HSSHA04_output.xlsx',
#  'BSB273DC15HSSHA05_output.xlsx',
#  'BSB273DC15HSSHA06_output.xlsx',
#  'BSB273DC15HSSHA07_output.xlsx',
#  'BSB273DC15HSSHA08_output.xlsx',
#  'BSB273DC15HSSHA09_output.xlsx',
#  'BSB273DC15HSSHA10_output.xlsx',
#  'BSB273DC15HSSHA11_output.xlsx',
#  'BSB273DC16HSSHA01_output.xlsx',
#  'BSB273DC16HSSHA02_output.xlsx',
#  'BSB273DC16HSSHA03_output.xlsx',
#  'BSB273DC16HSSHA04_output.xlsx',
#  'BSB273DC16HSSHA05_output.xlsx',
#  'BSB273DC16HSSHA06_output.xlsx',
#  'BSB273DC16HSSHA07_output.xlsx',
#  'BSB273DC16HSSHA08_output.xlsx',
#  'BSB273DC16HSSHA09_output.xlsx',
#  'BSB273DC16HSSHA10_output.xlsx',
#  'BSB273DC17HSSHA01_output.xlsx',
#  'BSB273DC17HSSHA02_output.xlsx',
#  'BSB273DC17HSSHA03_output.xlsx',
#  'BSB273DC17HSSHA04_output.xlsx',
#  'BSB273DC17HSSHA05_output.xlsx',
#  'BSB273DC17HSSHA06_output.xlsx',
#  'BSB273DC17HSSHA07_output.xlsx',
#  'BSB273DC17HSSHA08_output.xlsx',
#  'BSB273DC17HSSHA09_output.xlsx',
#  'BSB273DC17HSSHA10_output.xlsx',
#  'BSB273EC08HSSHA01_output.xlsx',
#  'BSB273EC08HSSHA02_output.xlsx',
#  'BSB273EC08HSSHA04_output.xlsx',
#  'BSB273EC08HSSHA05_output.xlsx',
#  'BSB273EC08HSSHA06_output.xlsx',
#  'BSB273EC08HSSHA07_output.xlsx',
#  'BSB273EC08HSSHA08_output.xlsx',
#  'BSB273EC08HSSHA09_output.xlsx',
#  'BSB273EC08HSSHA10_output.xlsx',
#  'BSB273EC09HSSHA01_output.xlsx',
#  'BSB273EC09HSSHA02_output.xlsx',
#  'BSB273EC09HSSHA03_output.xlsx',
#  'BSB273EC09HSSHA04_output.xlsx',
#  'BSB273EC09HSSHA05_output.xlsx',
#  'BSB273EC09HSSHA06_output.xlsx',
#  'BSB273EC09HSSHA07_output.xlsx',
#  'BSB273EC09HSSHA08_output.xlsx',
#  'BSB273EC09HSSHA09_output.xlsx',
#  'BSB273EC09HSSHA10_output.xlsx',
#  'BSB273EC10HSCOCAINESHA01_output.xlsx',
#  'BSB273EC10HSCOCAINESHA02_output.xlsx',
#  'BSB273EC10HSCOCAINESHA03_output.xlsx',
#  'BSB273EC10HSCOCAINESHA04_output.xlsx',
#  'BSB273EC10HSCOCAINESHA05_output.xlsx',
#  'BSB273EC10HSCOCAINESHA06_output.xlsx',
#  'BSB273EC10HSCOCAINESHA07_output.xlsx',
#  'BSB273EC10HSCOCAINESHA08_output.xlsx',
#  'BSB273EC10HSCOCAINESHA09_output.xlsx',
#  'BSB273EC10HSCOCAINESHA10_output.xlsx',
#  'BSB273EC11HSSHA01_output.xlsx',
#  'BSB273EC11HSSHA02_output.xlsx',
#  'BSB273EC11HSSHA03_output.xlsx',
#  'BSB273EC11HSSHA04_output.xlsx',
#  'BSB273EC11HSSHA05_output.xlsx',
#  'BSB273EC11HSSHA06_output.xlsx',
#  'BSB273EC11HSSHA08_output.xlsx',
#  'BSB273EC11HSSHA09_output.xlsx',
#  'BSB273EC11HSSHA10_output.xlsx',
#  'BSB273EC13HSSHA01_output.xlsx',
#  'BSB273EC13HSSHA02_output.xlsx',
#  'BSB273EC13HSSHA03_output.xlsx',
#  'BSB273EC13HSSHA04_output.xlsx',
#  'BSB273EC13HSSHA05_output.xlsx',
#  'BSB273EC13HSSHA06_output.xlsx',
#  'BSB273EC13HSSHA07_output.xlsx',
#  'BSB273EC13HSSHA08_output.xlsx',
#  'BSB273EC13HSSHA09_output.xlsx',
#  'BSB273EC13HSSHA10_output.xlsx',
#  'BSB273EC14HSSHA01_output.xlsx',
#  'BSB273EC14HSSHA02_output.xlsx',
#  'BSB273EC14HSSHA03_output.xlsx',
#  'BSB273EC14HSSHA04_output.xlsx',
#  'BSB273EC14HSSHA05_output.xlsx',
#  'BSB273EC14HSSHA06_output.xlsx',
#  'BSB273EC14HSSHA07_output.xlsx',
#  'BSB273EC14HSSHA08_output.xlsx',
#  'BSB273EC14HSSHA09_output.xlsx',
#  'BSB273EC14HSSHA10_output.xlsx',
#  'BSB273EC15HSSHA01_output.xlsx',
#  'BSB273EC15HSSHA02_output.xlsx',
#  'BSB273EC15HSSHA03_output.xlsx',
#  'BSB273EC15HSSHA04_output.xlsx',
#  'BSB273EC15HSSHA05_output.xlsx',
#  'BSB273EC15HSSHA06_output.xlsx',
#  'BSB273EC15HSSHA07_output.xlsx',
#  'BSB273EC15HSSHA08_output.xlsx',
#  'BSB273EC15HSSHA09_output.xlsx',
#  'BSB273EC15HSSHA10_output.xlsx',
#  'BSB273EC15HSSHA11_output.xlsx',
#  'BSB273EC16HSSHA01_output.xlsx',
#  'BSB273EC16HSSHA02_output.xlsx',
#  'BSB273EC16HSSHA03_output.xlsx',
#  'BSB273EC16HSSHA04_output.xlsx',
#  'BSB273EC16HSSHA05_output.xlsx',
#  'BSB273EC16HSSHA06_output.xlsx',
#  'BSB273EC16HSSHA07_output.xlsx',
#  'BSB273EC16HSSHA08_output.xlsx',
#  'BSB273EC16HSSHA09_output.xlsx',
#  'BSB273EC16HSSHA10_output.xlsx',
#  'BSB273EC17HSSHA01_output.xlsx',
#  'BSB273EC17HSSHA02_output.xlsx',
#  'BSB273EC17HSSHA03_output.xlsx',
#  'BSB273EC17HSSHA04_output.xlsx',
#  'BSB273EC17HSSHA05_output.xlsx',
#  'BSB273EC17HSSHA06_output.xlsx',
#  'BSB273EC17HSSHA07_output.xlsx',
#  'BSB273EC17HSSHA08_output.xlsx',
#  'BSB273EC17HSSHA09_output.xlsx',
#  'BSB273EC17HSSHA10_output.xlsx',
#  'C01HSSHA01_output.xlsx',
#  'C02HSSHA03_output.xlsx',
#  'C02HSSHA04_output.xlsx',
#  'C02HSSHA05_output.xlsx',
#  'C02HSSHA06_output.xlsx',
#  'C02HSSHA07_output.xlsx',
#  'C02HSSHA08_output.xlsx',
#  'C02HSSHA09_output.xlsx',
#  'C02HSSHA10_output.xlsx',
#  'C03HSSHA01_output.xlsx',
#  'C03HSSHA02_output.xlsx',
#  'C03HSSHA03_output.xlsx',
#  'C03HSSHA04_output.xlsx',
#  'C03HSSHA05_output.xlsx',
#  'C03HSSHA06_output.xlsx',
#  'C03HSSHA07_output.xlsx',
#  'C03HSSHA08_output.xlsx',
#  'C03HSSHA09_output.xlsx',
#  'C03HSSHA10_output.xlsx',
#  'C04HSSHA01_output.xlsx',
#  'C04HSSHA02_output.xlsx',
#  'C04HSSHA03_output.xlsx',
#  'C04HSSHA04_output.xlsx',
#  'C04HSSHA05_output.xlsx',
#  'C04HSSHA06_output.xlsx',
#  'C04HSSHA07_output.xlsx',
#  'C04HSSHA08_output.xlsx',
#  'C04HSSHA09_output.xlsx',
#  'C04HSSHA10_output.xlsx',
#  'C10HSSHA04_output.xlsx',
#  'C10HSSHA05_output.xlsx',
#  'C10HSSHA06_output.xlsx',
#  'C10HSSHA07_output.xlsx',
#  'C10HSSHA08_output.xlsx',
#  'C10HSSHA09_output.xlsx',
#  'C10HSSHA10_output.xlsx',
#  'MED1110C05HSSHA01_output.xlsx',
#  'MED1110C05HSSHA02_output.xlsx',
#  'MED1110C05HSSHA03_output.xlsx',
#  'MED1110C05HSSHA04_output.xlsx',
#  'MED1110C05HSSHA05_output.xlsx',
#  'MED1110C05HSSHA06_output.xlsx',
#  'MED1110C05HSSHA07_output.xlsx',
#  'MED1110C05HSSHA08_output.xlsx',
#  'MED1110C05HSSHA09_output.xlsx',
#  'MED1110C05HSSHA10_output.xlsx',
#  'MED1110C07HSSHA01_output.xlsx',
#  'MED1110C07HSSHA02_output.xlsx',
#  'MED1110C07HSSHA03_output.xlsx',
#  'MED1110C07HSSHA04_output.xlsx',
#  'MED1110C07HSSHA05_output.xlsx',
#  'MED1110C07HSSHA06_output.xlsx',
#  'MED1110C07HSSHA07_output.xlsx',
#  'MED1110C07HSSHA08_output.xlsx',
#  'MED1110C07HSSHA09_output.xlsx',
#  'MED1110C07HSSHA10_output.xlsx',
#  'MED1112C07HSSHA01_output.xlsx',
#  'MED1112C07HSSHA02_output.xlsx',
#  'MED1112C07HSSHA03_output.xlsx',
#  'MED1112C07HSSHA04_output.xlsx',
#  'MED1112C07HSSHA05_output.xlsx',
#  'MED1112C07HSSHA06_output.xlsx',
#  'MED1112C07HSSHA07_output.xlsx',
#  'MED1112C07HSSHA08_output.xlsx',
#  'MED1112C07HSSHA09_output.xlsx',
#  'MED1112C07HSSHA10_output.xlsx',
#  'MED1113C05HSSHA01_output.xlsx',
#  'MED1113C05HSSHA02_output.xlsx',
#  'MED1113C05HSSHA03_output.xlsx',
#  'MED1113C05HSSHA04_output.xlsx',
#  'MED1113C05HSSHA05_output.xlsx',
#  'MED1113C05HSSHA06_output.xlsx',
#  'MED1113C05HSSHA07_output.xlsx',
#  'MED1113C05HSSHA08_output.xlsx',
#  'MED1113C05HSSHA09_output.xlsx',
#  'MED1113C05HSSHA10_output.xlsx',
#  'MED1113C07HSSHA01_output.xlsx',
#  'MED1113C07HSSHA02_output.xlsx',
#  'MED1113C07HSSHA03_output.xlsx',
#  'MED1113C07HSSHA04_output.xlsx',
#  'MED1113C07HSSHA05_output.xlsx',
#  'MED1113C07HSSHA06_output.xlsx',
#  'MED1113C07HSSHA07_output.xlsx',
#  'MED1113C07HSSHA08_output.xlsx',
#  'MED1113C07HSSHA09_output.xlsx',
#  'MED1113C07HSSHA10_output.xlsx',
#  'MED1114C07HSSHA01_output.xlsx',
#  'MED1114C07HSSHA02_output.xlsx',
#  'MED1114C07HSSHA03_output.xlsx',
#  'MED1114C07HSSHA04_output.xlsx',
#  'MED1114C07HSSHA05_output.xlsx',
#  'MED1114C07HSSHA06_output.xlsx',
#  'MED1114C07HSSHA07_output.xlsx',
#  'MED1114C07HSSHA08_output.xlsx',
#  'MED1114C07HSSHA09_output.xlsx',
#  'MED1114C07HSSHA10_output.xlsx',
#  'MTF134BC18HSSHA01_output.xlsx',
#  'MTF134BC18HSSHA02_output.xlsx',
#  'MTF134BC18HSSHA03_output.xlsx',
#  'MTF134BC18HSSHA04_output.xlsx',
#  'MTF134BC18HSSHA05_output.xlsx',
#  'MTF134BC18HSSHA06_output.xlsx',
#  'MTF134BC18HSSHA07_output.xlsx',
#  'MTF134BC18HSSHA08_output.xlsx',
#  'MTF134BC18HSSHA09_output.xlsx',
#  'MTF134BC18HSSHA10_output.xlsx',
#  'MTF134BC18HSSHA11_output.xlsx',
#  'MTF134BC19HSSHA01_output.xlsx',
#  'MTF134BC19HSSHA02_output.xlsx',
#  'MTF134BC19HSSHA03_output.xlsx',
#  'MTF134BC19HSSHA04_output.xlsx',
#  'MTF134BC19HSSHA05_output.xlsx',
#  'MTF134BC19HSSHA06_output.xlsx',
#  'MTF134BC19HSSHA07_output.xlsx',
#  'MTF134BC19HSSHA08_output.xlsx',
#  'MTF134BC19HSSHA09_output.xlsx',
#  'MTF134BC19HSSHA10_output.xlsx',
#  'MTF134BC19HSSHA11_output.xlsx',
#  'MTF134BC20HSSHA01_output.xlsx',
#  'MTF134BC20HSSHA02_output.xlsx',
#  'MTF134BC20HSSHA03_output.xlsx',
#  'MTF134BC20HSSHA04_output.xlsx',
#  'MTF134BC20HSSHA05_output.xlsx',
#  'MTF134BC20HSSHA06_output.xlsx',
#  'MTF134BC20HSSHA07_output.xlsx',
#  'MTF134BC20HSSHA08_output.xlsx',
#  'MTF134BC20HSSHA09_output.xlsx',
#  'MTF134BC20HSSHA10_output.xlsx',
#  'MTF134CC18HSSHA01_output.xlsx',
#  'MTF134CC18HSSHA02_output.xlsx',
#  'MTF134CC18HSSHA03_output.xlsx',
#  'MTF134CC18HSSHA04_output.xlsx',
#  'MTF134CC18HSSHA05_output.xlsx',
#  'MTF134CC18HSSHA06_output.xlsx',
#  'MTF134CC18HSSHA07_output.xlsx',
#  'MTF134CC18HSSHA08_output.xlsx',
#  'MTF134CC18HSSHA09_output.xlsx',
#  'MTF134CC18HSSHA10_output.xlsx',
#  'MTF134CC18HSSHA11_output.xlsx',
#  'MTF134CC19HSSHA01_output.xlsx',
#  'MTF134CC19HSSHA02_output.xlsx',
#  'MTF134CC19HSSHA03_output.xlsx',
#  'MTF134CC19HSSHA04_output.xlsx',
#  'MTF134CC19HSSHA05_output.xlsx',
#  'MTF134CC19HSSHA06_output.xlsx',
#  'MTF134CC19HSSHA07_output.xlsx',
#  'MTF134CC19HSSHA08_output.xlsx',
#  'MTF134CC19HSSHA09_output.xlsx',
#  'MTF134CC19HSSHA10_output.xlsx',
#  'MTF134CC19HSSHA11_output.xlsx',
#  'MTF134CC20HSSHA01_output.xlsx',
#  'MTF134CC20HSSHA02_output.xlsx',
#  'MTF134CC20HSSHA03_output.xlsx',
#  'MTF134CC20HSSHA04_output.xlsx',
#  'MTF134CC20HSSHA05_output.xlsx',
#  'MTF134CC20HSSHA06_output.xlsx',
#  'MTF134CC20HSSHA07_output.xlsx',
#  'MTF134CC20HSSHA08_output.xlsx',
#  'MTF134CC20HSSHA09_output.xlsx',
#  'MTF134CC20HSSHA10_output.xlsx',
#  'MTF134DC18HSSHA01_output.xlsx',
#  'MTF134DC18HSSHA02_output.xlsx',
#  'MTF134DC18HSSHA03_output.xlsx',
#  'MTF134DC18HSSHA04_output.xlsx',
#  'MTF134DC18HSSHA05_output.xlsx',
#  'MTF134DC18HSSHA06_output.xlsx',
#  'MTF134DC18HSSHA07_output.xlsx',
#  'MTF134DC18HSSHA08_output.xlsx',
#  'MTF134DC18HSSHA09_output.xlsx',
#  'MTF134DC18HSSHA10_output.xlsx',
#  'MTF134DC18HSSHA11_output.xlsx',
#  'MTF134DC19HSSHA01_output.xlsx',
#  'MTF134DC19HSSHA02_output.xlsx',
#  'MTF134DC19HSSHA03_output.xlsx',
#  'MTF134DC19HSSHA04_output.xlsx',
#  'MTF134DC19HSSHA05_output.xlsx',
#  'MTF134DC19HSSHA06_output.xlsx',
#  'MTF134DC19HSSHA07_output.xlsx',
#  'MTF134DC19HSSHA08_output.xlsx',
#  'MTF134DC19HSSHA09_output.xlsx',
#  'MTF134DC19HSSHA10_output.xlsx',
#  'MTF134DC19HSSHA11_output.xlsx',
#  'MTF134DC20HSSHA01_output.xlsx',
#  'MTF134DC20HSSHA02_output.xlsx',
#  'MTF134DC20HSSHA03E_output.xlsx',
#  'MTF134DC20HSSHA03_output.xlsx',
#  'MTF134DC20HSSHA04_output.xlsx',
#  'MTF134DC20HSSHA05_output.xlsx',
#  'MTF134DC20HSSHA06_output.xlsx',
#  'MTF134DC20HSSHA07_output.xlsx',
#  'MTF134DC20HSSHA08_output.xlsx',
#  'MTF134DC20HSSHA09_output.xlsx',
#  'MTF134DC20HSSHA10_output.xlsx',
#  'MTF134EC18HSSHA01_output.xlsx',
#  'MTF134EC18HSSHA02_output.xlsx',
#  'MTF134EC18HSSHA03_output.xlsx',
#  'MTF134EC18HSSHA04_output.xlsx',
#  'MTF134EC18HSSHA05_output.xlsx',
#  'MTF134EC18HSSHA06_output.xlsx',
#  'MTF134EC18HSSHA07_output.xlsx',
#  'MTF134EC18HSSHA08_output.xlsx',
#  'MTF134EC18HSSHA09_output.xlsx',
#  'MTF134EC18HSSHA10_output.xlsx',
#  'MTF134EC18HSSHA11_output.xlsx',
#  'MTF134EC19HSSHA01_output.xlsx',
#  'MTF134EC19HSSHA02_output.xlsx',
#  'MTF134EC19HSSHA03_output.xlsx',
#  'MTF134EC19HSSHA04_output.xlsx',
#  'MTF134EC19HSSHA05_output.xlsx',
#  'MTF134EC19HSSHA06_output.xlsx',
#  'MTF134EC19HSSHA07_output.xlsx',
#  'MTF134EC19HSSHA08_output.xlsx',
#  'MTF134EC19HSSHA09_output.xlsx',
#  'MTF134EC19HSSHA10_output.xlsx',
#  'MTF134EC19HSSHA11_output.xlsx',
#  'MTF134EC20HSSHA01_output.xlsx',
#  'MTF134EC20HSSHA02_output.xlsx',
#  'MTF134EC20HSSHA04_output.xlsx',
#  'MTF134EC20HSSHA05_output.xlsx',
#  'MTF134EC20HSSHA06_output.xlsx',
#  'MTF134EC20HSSHA07_output.xlsx',
#  'MTF134EC20HSSHA08_output.xlsx',
#  'MTF134EC20HSSHA09_output.xlsx',
#  'MTF134EC20HSSHA10_output.xlsx']

# %%
len(files)
# Out:
# 565

# %%
file = files[0]

# %%
transform_data(file, input_path, output_path, parsers, drug)

# %%
def transform_data(file, input_path, output_path, parsers, drug):
    # import data and transpose
    filepath = os.path.join(input_path, file)
    df_raw = pd.read_excel(filepath).T
    df_raw.reset_index(inplace=True)

    # modify the header
    new_header = df_raw.iloc[0]   #grab the first row for the header
    df = df_raw[1:]               #take the data except the header row
    df.columns = new_header 
    df.reset_index(drop=True, inplace=True)
    df.drop(['Filename', 'Experiment', 'Group', 'MSN', 'FR'], axis=1, inplace=True)
    df.drop_duplicates(inplace=True)
    
    # patch
    if ('Timeout Press 1') not in df.columns:
        df['Timeout Press 1'] = [0] * len(df)
        
    # change data types
    cols = df.columns.tolist()
    for col in cols:
        name = col.lower()
        if ('active' in name) or ('reward' in name) or ('timeout' in name) or (name == 'box'):
            df[col] = df[col].astype('int32')
        elif ('date' in name):
            df[col] = df[col].apply(lambda x: pd.to_datetime(x, format='%Y-%m-%d', errors='ignore'))
        elif ('time' in name):
            df[col] = df[col].apply(lambda x: datetime.strptime(x, "%H:%M:%S").time())
        else:
            pass
        
    # group the timestamps
    colnames = df.columns.tolist()
    active_col_begin = colnames.index('Active 1')
    inactive_col_begin = colnames.index('Inactive 1')
    reward_col_begin = colnames.index('Reward 1')
    timeout_col_begin = colnames.index('Timeout Press 1')
    idx_end = df.shape[1]
    df['Active Timestamps'] = df.iloc[:, active_col_begin:inactive_col_begin].values.tolist()
    df['Inactive Timestamps'] = df.iloc[:, inactive_col_begin:reward_col_begin].values.tolist()
    df['Reward Timestamps'] = df.iloc[:, reward_col_begin:timeout_col_begin].values.tolist()
    df['Timeout Timestamps'] = df.iloc[:, timeout_col_begin:idx_end].values.tolist()
    
    # reorganize the columns
    timestamp_col_begin = df.columns.tolist().index('Active Timestamps')
    df.drop(df.iloc[:, active_col_begin:timestamp_col_begin], inplace=True, axis=1)
    df.rename(columns={"Reward": "Reward Presses"}, inplace=True)
    df['Timeout Presses'] = df['Active Lever Presses'] - df['Reward Presses']

    # parse the filename
    if file[0] == 'C':
        parser = parsers[1]
        cohort, trial_id = re.findall(parser, file)[0]
        room = 'N/A'
    else:
        parser = parsers[0]
        room, cohort, trial_id = re.findall(parser, file)[0]

    df['Room'] = [room] * len(df)
    df['Cohort'] = [cohort] * len(df)
    df['Cohort'] = df['Cohort'].apply(lambda x: int(x[1:]))
    df['Trial ID'] = [trial_id] * len(df)
    df['Drug'] = [drug] * len(df)

    # get the final output
    new_columns = ['Subject','Room','Cohort','Trial ID','Drug','Box','Start Time','End Time','Start Date','End Date',
                   'Active Lever Presses','Inactive Lever Presses','Reward Presses','Timeout Presses',
                   'Active Timestamps','Inactive Timestamps','Reward Timestamps','Timeout Timestamps']
    df = df[new_columns]
    
    # merge in the RFID and reorganize the column formats
    df.rename(columns=str.lower,inplace=True)
    if drug.lower() == 'cocaine':
        rfid_to_merge = RFID_COC
    if drug.lower() == 'oxycodone':
        rfid_to_merge = RFID_OXY

    df = pd.merge(df, rfid_to_merge,  how='left', on = ['subject'])
    old_columns = df.columns.tolist()
    new_columns = [old_columns[-1]] + old_columns[:-1]
    df = df[new_columns]
    df.columns = df.columns.str.replace(' ','_')
    df.fillna({'rfid':-999}, inplace=True)
    
    filename = file[:-11] + 'transformed.csv'
    df.to_csv(os.path.join(output_path, filename))

# %%
files[248]
# Out:
# 'BSB273DC17HSSHA07_output.xlsx'

# %%
for i in tqdm(range(len(files))):
    transform_data(files[i], input_path, output_path, parsers, drug)
# Out:
# 100%|███████████████████████████████████████████| 565/565 [20:58<00:00,  2.23s/it]
